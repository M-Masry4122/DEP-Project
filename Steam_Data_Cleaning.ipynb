# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
csv_files = glob.glob('Full Data/*.csv')
dfs = []

for file in csv_files:
    dfn = pd.read_csv(file)
    dfs.append(dfn)

df = pd.concat(dfs)

# %%
df
# Out:
#                            Name                   Review Number Of Reviews  \
# 0              Counter-Strike 2          Mostly Positive          (58,000)
# 1            NARAKA: BLADEPOINT          Mostly Positive           (6,993)
# 2                Lethal Company  Overwhelmingly Positive          (57,723)
# 3            Grand Theft Auto V            Very Positive          (21,480)
# 4                        Dota 2          Mostly Positive          (21,267)
# ...                         ...                      ...               ...
# 2447                  Hyper Jam            Very Positive             (396)
# 2448  Please, Touch The Artwork            Very Positive             (148)
# 2449         Star of Providence          Mostly Positive              (14)
# 2450        Kinkoi: Golden Time            Very Positive              (11)
# 2451                The Council                    Mixed              (30)
#
#                                              Genre  \
# 0                         ['Action, Free to Play']
# 1     ['Action, Adventure, Massively Multiplayer']
# 2       ['Action, Adventure, Indie, Early Access']
# 3                            ['Action, Adventure']
# 4               ['Action, Strategy, Free to Play']
# ...                                            ...
# 2447                             ['Action, Indie']
# 2448                             ['Casual, Indie']
# 2449                             ['Action, Indie']
# 2450                     ['Adventure, Simulation']
# 2451                            ['Adventure, RPG']
#
#                                                    Tags  \
# 0     ['Cross-Platform Multiplayer', 'Steam Trading ...
# 1                    ['Online PvP', 'In-App Purchases']
# 2                     ['Single-player', 'Online Co-op']
# 3     ['Single-player', 'Online PvP', 'Online Co-op'...
# 4     ['Steam Trading Cards', 'Steam Workshop', 'Ste...
# ...                                                 ...
# 2447  ['Online PvP', 'Shared/Split Screen PvP', 'Cro...
# 2448            ['Single-player', 'Steam Achievements']
# 2449  ['Single-player', 'Steam Achievements', 'Steam...
# 2450  ['Single-player', 'Steam Achievements', 'Steam...
# 2451  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                           Dev_Info         Developer  \
# 0                         ['Action, Free to Play']             Valve
# 1     ['Action, Adventure, Massively Multiplayer']  24 Entertainment
# 2       ['Action, Adventure, Indie, Early Access']          Zeekerss
# 3                            ['Action, Adventure']    Rockstar North
# 4               ['Action, Strategy, Free to Play']             Valve
# ...                                            ...               ...
# 2447                             ['Action, Indie']        Bit Dragon
# 2448                             ['Casual, Indie']  Thomas Waterzooi
# 2449                             ['Action, Indie']         Team D-13
# 2450                     ['Adventure, Simulation']      Saga Planets
# 2451                            ['Adventure, RPG']      Big Bad Wolf
#
#                  Publisher  Release_Date  \
# 0                    Valve  21 Aug, 2012
# 1     NetEase Games Global  12 Aug, 2021
# 2                 Zeekerss  24 Oct, 2023
# 3           Rockstar Games  14 Apr, 2015
# 4                    Valve   9 Jul, 2013
# ...                    ...           ...
# 2447            Bit Dragon  12 Feb, 2019
# 2448      Thomas Waterzooi  26 Jan, 2022
# 2449             Team D-13   7 Jun, 2017
# 2450         NekoNyan Ltd.  15 Jul, 2022
# 2451   Focus Entertainment  13 Mar, 2018
#
#                                                    link   Price
# 0     https://store.steampowered.com/app/730/Counter...    Free
# 1     https://store.steampowered.com/app/1203220/NAR...    Free
# 2     https://store.steampowered.com/app/1966720/Let...   $5.79
# 3     https://store.steampowered.com/app/271590/Gran...  $19.80
# 4     https://store.steampowered.com/app/570/Dota_2/...    Free
# ...                                                 ...     ...
# 2447  https://store.steampowered.com/app/556050/Hype...   $7.29
# 2448  https://store.steampowered.com/app/1097100/Ple...   $3.99
# 2449  https://store.steampowered.com/app/603960/Star...   $7.99
# 2450  https://store.steampowered.com/app/1985260/Kin...  $29.99
# 2451  https://store.steampowered.com/app/287630/The_...    Free
#
# [2452 rows x 11 columns]

# %%
df.dropna
df = df.drop_duplicates()
df
# Out:
#                            Name                   Review Number Of Reviews  \
# 0              Counter-Strike 2          Mostly Positive          (58,000)
# 1            NARAKA: BLADEPOINT          Mostly Positive           (6,993)
# 2                Lethal Company  Overwhelmingly Positive          (57,723)
# 3            Grand Theft Auto V            Very Positive          (21,480)
# 4                        Dota 2          Mostly Positive          (21,267)
# ...                         ...                      ...               ...
# 2447                  Hyper Jam            Very Positive             (396)
# 2448  Please, Touch The Artwork            Very Positive             (148)
# 2449         Star of Providence          Mostly Positive              (14)
# 2450        Kinkoi: Golden Time            Very Positive              (11)
# 2451                The Council                    Mixed              (30)
#
#                                              Genre  \
# 0                         ['Action, Free to Play']
# 1     ['Action, Adventure, Massively Multiplayer']
# 2       ['Action, Adventure, Indie, Early Access']
# 3                            ['Action, Adventure']
# 4               ['Action, Strategy, Free to Play']
# ...                                            ...
# 2447                             ['Action, Indie']
# 2448                             ['Casual, Indie']
# 2449                             ['Action, Indie']
# 2450                     ['Adventure, Simulation']
# 2451                            ['Adventure, RPG']
#
#                                                    Tags  \
# 0     ['Cross-Platform Multiplayer', 'Steam Trading ...
# 1                    ['Online PvP', 'In-App Purchases']
# 2                     ['Single-player', 'Online Co-op']
# 3     ['Single-player', 'Online PvP', 'Online Co-op'...
# 4     ['Steam Trading Cards', 'Steam Workshop', 'Ste...
# ...                                                 ...
# 2447  ['Online PvP', 'Shared/Split Screen PvP', 'Cro...
# 2448            ['Single-player', 'Steam Achievements']
# 2449  ['Single-player', 'Steam Achievements', 'Steam...
# 2450  ['Single-player', 'Steam Achievements', 'Steam...
# 2451  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                           Dev_Info         Developer  \
# 0                         ['Action, Free to Play']             Valve
# 1     ['Action, Adventure, Massively Multiplayer']  24 Entertainment
# 2       ['Action, Adventure, Indie, Early Access']          Zeekerss
# 3                            ['Action, Adventure']    Rockstar North
# 4               ['Action, Strategy, Free to Play']             Valve
# ...                                            ...               ...
# 2447                             ['Action, Indie']        Bit Dragon
# 2448                             ['Casual, Indie']  Thomas Waterzooi
# 2449                             ['Action, Indie']         Team D-13
# 2450                     ['Adventure, Simulation']      Saga Planets
# 2451                            ['Adventure, RPG']      Big Bad Wolf
#
#                  Publisher  Release_Date  \
# 0                    Valve  21 Aug, 2012
# 1     NetEase Games Global  12 Aug, 2021
# 2                 Zeekerss  24 Oct, 2023
# 3           Rockstar Games  14 Apr, 2015
# 4                    Valve   9 Jul, 2013
# ...                    ...           ...
# 2447            Bit Dragon  12 Feb, 2019
# 2448      Thomas Waterzooi  26 Jan, 2022
# 2449             Team D-13   7 Jun, 2017
# 2450         NekoNyan Ltd.  15 Jul, 2022
# 2451   Focus Entertainment  13 Mar, 2018
#
#                                                    link   Price
# 0     https://store.steampowered.com/app/730/Counter...    Free
# 1     https://store.steampowered.com/app/1203220/NAR...    Free
# 2     https://store.steampowered.com/app/1966720/Let...   $5.79
# 3     https://store.steampowered.com/app/271590/Gran...  $19.80
# 4     https://store.steampowered.com/app/570/Dota_2/...    Free
# ...                                                 ...     ...
# 2447  https://store.steampowered.com/app/556050/Hype...   $7.29
# 2448  https://store.steampowered.com/app/1097100/Ple...   $3.99
# 2449  https://store.steampowered.com/app/603960/Star...   $7.99
# 2450  https://store.steampowered.com/app/1985260/Kin...  $29.99
# 2451  https://store.steampowered.com/app/287630/The_...    Free
#
# [2452 rows x 11 columns]

# %%
# df.drop('link', axis=1, inplace=True)
df
# Out:
#                            Name                   Review Number Of Reviews  \
# 0              Counter-Strike 2          Mostly Positive          (58,000)
# 1            NARAKA: BLADEPOINT          Mostly Positive           (6,993)
# 2                Lethal Company  Overwhelmingly Positive          (57,723)
# 3            Grand Theft Auto V            Very Positive          (21,480)
# 4                        Dota 2          Mostly Positive          (21,267)
# ...                         ...                      ...               ...
# 2447                  Hyper Jam            Very Positive             (396)
# 2448  Please, Touch The Artwork            Very Positive             (148)
# 2449         Star of Providence          Mostly Positive              (14)
# 2450        Kinkoi: Golden Time            Very Positive              (11)
# 2451                The Council                    Mixed              (30)
#
#                                              Genre  \
# 0                         ['Action, Free to Play']
# 1     ['Action, Adventure, Massively Multiplayer']
# 2       ['Action, Adventure, Indie, Early Access']
# 3                            ['Action, Adventure']
# 4               ['Action, Strategy, Free to Play']
# ...                                            ...
# 2447                             ['Action, Indie']
# 2448                             ['Casual, Indie']
# 2449                             ['Action, Indie']
# 2450                     ['Adventure, Simulation']
# 2451                            ['Adventure, RPG']
#
#                                                    Tags  \
# 0     ['Cross-Platform Multiplayer', 'Steam Trading ...
# 1                    ['Online PvP', 'In-App Purchases']
# 2                     ['Single-player', 'Online Co-op']
# 3     ['Single-player', 'Online PvP', 'Online Co-op'...
# 4     ['Steam Trading Cards', 'Steam Workshop', 'Ste...
# ...                                                 ...
# 2447  ['Online PvP', 'Shared/Split Screen PvP', 'Cro...
# 2448            ['Single-player', 'Steam Achievements']
# 2449  ['Single-player', 'Steam Achievements', 'Steam...
# 2450  ['Single-player', 'Steam Achievements', 'Steam...
# 2451  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                           Dev_Info         Developer  \
# 0                         ['Action, Free to Play']             Valve
# 1     ['Action, Adventure, Massively Multiplayer']  24 Entertainment
# 2       ['Action, Adventure, Indie, Early Access']          Zeekerss
# 3                            ['Action, Adventure']    Rockstar North
# 4               ['Action, Strategy, Free to Play']             Valve
# ...                                            ...               ...
# 2447                             ['Action, Indie']        Bit Dragon
# 2448                             ['Casual, Indie']  Thomas Waterzooi
# 2449                             ['Action, Indie']         Team D-13
# 2450                     ['Adventure, Simulation']      Saga Planets
# 2451                            ['Adventure, RPG']      Big Bad Wolf
#
#                  Publisher  Release_Date   Price
# 0                    Valve  21 Aug, 2012    Free
# 1     NetEase Games Global  12 Aug, 2021    Free
# 2                 Zeekerss  24 Oct, 2023   $5.79
# 3           Rockstar Games  14 Apr, 2015  $19.80
# 4                    Valve   9 Jul, 2013    Free
# ...                    ...           ...     ...
# 2447            Bit Dragon  12 Feb, 2019   $7.29
# 2448      Thomas Waterzooi  26 Jan, 2022   $3.99
# 2449             Team D-13   7 Jun, 2017   $7.99
# 2450         NekoNyan Ltd.  15 Jul, 2022  $29.99
# 2451   Focus Entertainment  13 Mar, 2018    Free
#
# [2452 rows x 10 columns]
