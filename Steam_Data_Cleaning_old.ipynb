# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
csv_files = glob.glob('Full Data/*.csv')
dfs = []

for file in csv_files:
    dfn = pd.read_csv(file)
    dfs.append(dfn)

df = pd.concat(dfs)

# %%
df
# Out:
#                           Name                   Review Number Of Reviews  \
# 0             Counter-Strike 2          Mostly Positive          (58,000)
# 1           NARAKA: BLADEPOINT          Mostly Positive           (6,993)
# 2               Lethal Company  Overwhelmingly Positive          (57,723)
# 3           Grand Theft Auto V            Very Positive          (21,480)
# 4                       Dota 2          Mostly Positive          (21,267)
# ..                         ...                      ...               ...
# 493  Summoners War: Chronicles                    Mixed              -129
# 494          Dungeon Alchemist            Very Positive               -54
# 495                Bopl Battle  Overwhelmingly Positive            -1,081
# 496    DARK SOULS™: REMASTERED            Very Positive            -1,122
# 497            Winter Memories  Overwhelmingly Positive            -3,220
#
#                                                  Genre  \
# 0                             ['Action, Free to Play']
# 1         ['Action, Adventure, Massively Multiplayer']
# 2           ['Action, Adventure, Indie, Early Access']
# 3                                ['Action, Adventure']
# 4                   ['Action, Strategy, Free to Play']
# ..                                                 ...
# 493  ['Action, Adventure, Massively Multiplayer, RP...
# 494                              ['RPG, Early Access']
# 495                                         ['Action']
# 496                                         ['Action']
# 497             ['Adventure, Casual, RPG, Simulation']
#
#                                                   Tags  \
# 0    ['Cross-Platform Multiplayer', 'Steam Trading ...
# 1                   ['Online PvP', 'In-App Purchases']
# 2                    ['Single-player', 'Online Co-op']
# 3    ['Single-player', 'Online PvP', 'Online Co-op'...
# 4    ['Steam Trading Cards', 'Steam Workshop', 'Ste...
# ..                                                 ...
# 493  ['MMO', 'Online PvP', 'Online Co-op', 'Cross-P...
# 494  ['Single-player', 'Steam Workshop', 'Includes ...
# 495  ['Online PvP', 'Shared/Split Screen PvP', 'Onl...
# 496  ['Single-player', 'Steam Achievements', 'Remot...
# 497                   ['Single-player', 'Steam Cloud']
#
#                                               Dev_Info         Developer  \
# 0                             ['Action, Free to Play']             Valve
# 1         ['Action, Adventure, Massively Multiplayer']  24 Entertainment
# 2           ['Action, Adventure, Indie, Early Access']          Zeekerss
# 3                                ['Action, Adventure']    Rockstar North
# 4                   ['Action, Strategy, Free to Play']             Valve
# ..                                                 ...               ...
# 493  ['Action, Adventure, Massively Multiplayer, RP...            Com2uS
# 494                              ['RPG, Early Access']          Briganti
# 495                                         ['Action']    Johan Grönvall
# 496                                         ['Action']              QLOC
# 497             ['Adventure, Casual, RPG, Simulation']       Dojin Otome
#
#                 Publisher  Release_Date  \
# 0                   Valve  21 Aug, 2012
# 1    NetEase Games Global  12 Aug, 2021
# 2                Zeekerss  24 Oct, 2023
# 3          Rockstar Games  14 Apr, 2015
# 4                   Valve   9 Jul, 2013
# ..                    ...           ...
# 493                Com2uS  10 Nov, 2022
# 494              Briganti  31 Mar, 2022
# 495          Zapray Games  16 Nov, 2023
# 496     FromSoftware, Inc  24 May, 2018
# 497          Kagura Games   6 Jan, 2024
#
#                                                   link           Price
# 0    https://store.steampowered.com/app/730/Counter...            Free
# 1    https://store.steampowered.com/app/1203220/NAR...            Free
# 2    https://store.steampowered.com/app/1966720/Let...           $5.79
# 3    https://store.steampowered.com/app/271590/Gran...          $19.80
# 4    https://store.steampowered.com/app/570/Dota_2/...            Free
# ..                                                 ...             ...
# 493  https://store.steampowered.com/app/2167580/Sum...            Free
# 494  https://store.steampowered.com/app/1588530/Dun...         $44.99
# 495  https://store.steampowered.com/app/1686940/Bop...  $5.79\r\n$4.34
# 496  https://store.steampowered.com/app/570940/DARK...         $24.99
# 497  https://store.steampowered.com/app/2495450/Win...          $2.00
#
# [2950 rows x 11 columns]

# %%
df.dropna
df = df.drop_duplicates(subset='link', keep='first')
df
# Out:
#                              Name                   Review Number Of Reviews  \
# 0                Counter-Strike 2          Mostly Positive          (58,000)
# 1              NARAKA: BLADEPOINT          Mostly Positive           (6,993)
# 2                  Lethal Company  Overwhelmingly Positive          (57,723)
# 3              Grand Theft Auto V            Very Positive          (21,480)
# 4                          Dota 2          Mostly Positive          (21,267)
# ..                            ...                      ...               ...
# 383       Assassin's Creed® Unity            Very Positive              -573
# 384                      LONESTAR            Very Positive              -638
# 388                     Hydroneer          Mostly Positive              -323
# 437  Call of Duty®: Black Ops III            Very Positive            117755
# 440                      V Rising            Very Positive             67449
#
#                                                  Genre  \
# 0                             ['Action, Free to Play']
# 1         ['Action, Adventure, Massively Multiplayer']
# 2           ['Action, Adventure, Indie, Early Access']
# 3                                ['Action, Adventure']
# 4                   ['Action, Strategy, Free to Play']
# ..                                                 ...
# 383                              ['Action, Adventure']
# 384  ['Adventure, Indie, RPG, Strategy, Early Access']
# 388  ['Adventure, Casual, Indie, Simulation, Strate...
# 437                              ['Action, Adventure']
# 440  ['Action, Adventure, Massively Multiplayer, Ea...
#
#                                                   Tags  \
# 0    ['Cross-Platform Multiplayer', 'Steam Trading ...
# 1                   ['Online PvP', 'In-App Purchases']
# 2                    ['Single-player', 'Online Co-op']
# 3    ['Single-player', 'Online PvP', 'Online Co-op'...
# 4    ['Steam Trading Cards', 'Steam Workshop', 'Ste...
# ..                                                 ...
# 383              ['Single-player', 'In-App Purchases']
# 384  ['Single-player', 'Steam Achievements', 'Steam...
# 388  ['Single-player', 'Shared/Split Screen Co-op',...
# 437  ['Single-player', 'Steam Achievements', 'Steam...
# 440  ['Single-player', 'Online PvP', 'LAN PvP', 'On...
#
#                                               Dev_Info          Developer  \
# 0                             ['Action, Free to Play']              Valve
# 1         ['Action, Adventure, Massively Multiplayer']   24 Entertainment
# 2           ['Action, Adventure, Indie, Early Access']           Zeekerss
# 3                                ['Action, Adventure']     Rockstar North
# 4                   ['Action, Strategy, Free to Play']              Valve
# ..                                                 ...                ...
# 383                              ['Action, Adventure']            Ubisoft
# 384  ['Adventure, Indie, RPG, Strategy, Early Access']          Math Tide
# 388  ['Adventure, Casual, Indie, Simulation, Strate...  Foulball Hangover
# 437                              ['Action, Adventure']           Treyarch
# 440  ['Action, Adventure, Massively Multiplayer, Ea...   Stunlock Studios
#
#                 Publisher  Release_Date  \
# 0                   Valve  21 Aug, 2012
# 1    NetEase Games Global  12 Aug, 2021
# 2                Zeekerss  24 Oct, 2023
# 3          Rockstar Games  14 Apr, 2015
# 4                   Valve   9 Jul, 2013
# ..                    ...           ...
# 383               Ubisoft  13 Nov, 2014
# 384        Thermite Games  18 Jan, 2024
# 388     Foulball Hangover   8 May, 2020
# 437            Activision   6 Nov, 2015
# 440      Stunlock Studios  17 May, 2022
#
#                                                   link            Price
# 0    https://store.steampowered.com/app/730/Counter...             Free
# 1    https://store.steampowered.com/app/1203220/NAR...             Free
# 2    https://store.steampowered.com/app/1966720/Let...            $5.79
# 3    https://store.steampowered.com/app/271590/Gran...           $19.80
# 4    https://store.steampowered.com/app/570/Dota_2/...             Free
# ..                                                 ...              ...
# 383  https://store.steampowered.com/app/289650/Assa...          $23.99
# 384  https://store.steampowered.com/app/2056210/LON...           $5.79
# 388  https://store.steampowered.com/app/1106840/Hyd...          $14.99
# 437  https://store.steampowered.com/app/311210/Call...          $59.99
# 440  https://store.steampowered.com/app/1604030/V_R...  $10.49\r\n$8.39
#
# [2608 rows x 11 columns]

# %%
df.drop('link', axis=1, inplace=True)
df
# Out:
# C:\Users\Masry\AppData\Local\Temp\ipykernel_13472\1254760470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('link', axis=1, inplace=True)
#                         Name                   Review Number Of Reviews  \
# 0           Counter-Strike 2          Mostly Positive          (58,000)
# 1         NARAKA: BLADEPOINT          Mostly Positive           (6,993)
# 2             Lethal Company  Overwhelmingly Positive          (57,723)
# 3         Grand Theft Auto V            Very Positive          (21,480)
# 4                     Dota 2          Mostly Positive          (21,267)
# ..                       ...                      ...               ...
# 485           Limbus Company            Very Positive             27827
# 488     GUILTY GEAR -STRIVE-            Very Positive              -783
# 490         SONIC SUPERSTARS                    Mixed               -69
# 495              Bopl Battle  Overwhelmingly Positive            -1,081
# 496  DARK SOULS™: REMASTERED            Very Positive            -1,122
#
#                                             Genre  \
# 0                        ['Action, Free to Play']
# 1    ['Action, Adventure, Massively Multiplayer']
# 2      ['Action, Adventure, Indie, Early Access']
# 3                           ['Action, Adventure']
# 4              ['Action, Strategy, Free to Play']
# ..                                            ...
# 485                     ['Action, RPG, Strategy']
# 488                                    ['Action']
# 490                                    ['Action']
# 495                                    ['Action']
# 496                                    ['Action']
#
#                                                   Tags  \
# 0    ['Cross-Platform Multiplayer', 'Steam Trading ...
# 1                   ['Online PvP', 'In-App Purchases']
# 2                    ['Single-player', 'Online Co-op']
# 3    ['Single-player', 'Online PvP', 'Online Co-op'...
# 4    ['Steam Trading Cards', 'Steam Workshop', 'Ste...
# ..                                                 ...
# 485              ['Single-player', 'In-App Purchases']
# 488  ['Single-player', 'Online PvP', 'Shared/Split ...
# 490  ['Single-player', 'Online PvP', 'Shared/Split ...
# 495  ['Online PvP', 'Shared/Split Screen PvP', 'Onl...
# 496  ['Single-player', 'Steam Achievements', 'Remot...
#
#                                          Dev_Info         Developer  \
# 0                        ['Action, Free to Play']             Valve
# 1    ['Action, Adventure, Massively Multiplayer']  24 Entertainment
# 2      ['Action, Adventure, Indie, Early Access']          Zeekerss
# 3                           ['Action, Adventure']    Rockstar North
# 4              ['Action, Strategy, Free to Play']             Valve
# ..                                            ...               ...
# 485                     ['Action, RPG, Strategy']       ProjectMoon
# 488                                    ['Action']  Arc System Works
# 490                                    ['Action']              SEGA
# 495                                    ['Action']    Johan Grönvall
# 496                                    ['Action']              QLOC
#
#                 Publisher  Release_Date             Price
# 0                   Valve  21 Aug, 2012              Free
# 1    NetEase Games Global  12 Aug, 2021              Free
# 2                Zeekerss  24 Oct, 2023             $5.79
# 3          Rockstar Games  14 Apr, 2015            $19.80
# 4                   Valve   9 Jul, 2013              Free
# ..                    ...           ...               ...
# 485           ProjectMoon  27 Feb, 2023              Free
# 488      Arc System Works  11 Jun, 2021           $19.99
# 490                  SEGA  17 Oct, 2023  $59.99\r\n$29.99
# 495          Zapray Games  16 Nov, 2023    $5.79\r\n$4.34
# 496     FromSoftware, Inc  24 May, 2018           $24.99
#
# [2942 rows x 10 columns]
